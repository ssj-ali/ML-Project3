# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
get_ipython().run_line_magic('matplotlib', 'inline')
import seaborn as sns

# %%
names=['a{}'.format(i) for i in range(1, 61)]
names.append('Result')
train = pd.read_csv(r'ML-Project3/train.csv', names=names)

# %%
train.head()
# Out:
#        a1      a2      a3      a4      a5      a6      a7      a8      a9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#       a10   ...       a52     a53     a54     a55     a56     a57     a58  \
# 0  0.2111   ...    0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872   ...    0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194   ...    0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264   ...    0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459   ...    0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#       a59     a60  Result
# 0  0.0090  0.0032       R
# ...

# %%
train.isnull()
# Out:
#         a1     a2     a3     a4     a5     a6     a7     a8     a9    a10  \
# 0    False  False  False  False  False  False  False  False  False  False
# 1    False  False  False  False  False  False  False  False  False  False
# 2    False  False  False  False  False  False  False  False  False  False
# 3    False  False  False  False  False  False  False  False  False  False
# 4    False  False  False  False  False  False  False  False  False  False
# 5    False  False  False  False  False  False  False  False  False  False
# 6    False  False  False  False  False  False  False  False  False  False
# 7    False  False  False  False  False  False  False  False  False  False
# 8    False  False  False  False  False  False  False  False  False  False
# 9    False  False  False  False  False  False  False  False  False  False
# 10   False  False  False  False  False  False  False  False  False  False
# 11   False  False  False  False  False  False  False  False  False  False
# ...

# %%
sns.set_style('whitegrid')

# %%
sns.countplot(x='Result',data=train,palette='Set2')

# %%
result=pd.get_dummies(train['Result'],drop_first=True)
train.head()
# Out:
#        a1      a2      a3      a4      a5      a6      a7      a8      a9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#       a10   ...       a52     a53     a54     a55     a56     a57     a58  \
# 0  0.2111   ...    0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084
# 1  0.2872   ...    0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049
# 2  0.6194   ...    0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164
# 3  0.1264   ...    0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044
# 4  0.4459   ...    0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048
#
#       a59     a60  Result
# 0  0.0090  0.0032       R
# ...

# %%
train.drop(['Result'],axis=1,inplace=True)
train.head()
# Out:
#        a1      a2      a3      a4      a5      a6      a7      a8      a9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#       a10   ...       a51     a52     a53     a54     a55     a56     a57  \
# 0  0.2111   ...    0.0232  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180
# 1  0.2872   ...    0.0125  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140
# 2  0.6194   ...    0.0033  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316
# 3  0.1264   ...    0.0241  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050
# 4  0.4459   ...    0.0156  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072
#
#       a58     a59     a60
# 0  0.0084  0.0090  0.0032
# ...

# %%
train = pd.concat([train, result],axis=1)

# %%
train.head()
# Out:
#        a1      a2      a3      a4      a5      a6      a7      a8      a9  \
# 0  0.0200  0.0371  0.0428  0.0207  0.0954  0.0986  0.1539  0.1601  0.3109
# 1  0.0453  0.0523  0.0843  0.0689  0.1183  0.2583  0.2156  0.3481  0.3337
# 2  0.0262  0.0582  0.1099  0.1083  0.0974  0.2280  0.2431  0.3771  0.5598
# 3  0.0100  0.0171  0.0623  0.0205  0.0205  0.0368  0.1098  0.1276  0.0598
# 4  0.0762  0.0666  0.0481  0.0394  0.0590  0.0649  0.1209  0.2467  0.3564
#
#       a10 ...     a52     a53     a54     a55     a56     a57     a58     a59  \
# 0  0.2111 ...  0.0027  0.0065  0.0159  0.0072  0.0167  0.0180  0.0084  0.0090
# 1  0.2872 ...  0.0084  0.0089  0.0048  0.0094  0.0191  0.0140  0.0049  0.0052
# 2  0.6194 ...  0.0232  0.0166  0.0095  0.0180  0.0244  0.0316  0.0164  0.0095
# 3  0.1264 ...  0.0121  0.0036  0.0150  0.0085  0.0073  0.0050  0.0044  0.0040
# 4  0.4459 ...  0.0031  0.0054  0.0105  0.0110  0.0015  0.0072  0.0048  0.0107
#
#       a60  R
# 0  0.0032  1
# 1  0.0044  1
# ...

# %%
from sklearn.linear_model import LogisticRegression

# %%
names2=['a{}'.format(i) for i in range(1, 61)]
test = pd.read_csv(r'ML-Project3/test1.csv', names=names2 )

# %%
test.head()
# Out:
#        a1      a2      a3      a4      a5      a6      a7      a8      a9  \
# 0  0.0089  0.0274  0.0248  0.0237  0.0224  0.0845  0.1488  0.1224  0.1569
# 1  0.0473  0.0509  0.0819  0.1252  0.1783  0.3070  0.3008  0.2362  0.3830
# 2  0.0158  0.0239  0.0150  0.0494  0.0988  0.1425  0.1463  0.1219  0.1697
# 3  0.0664  0.0575  0.0842  0.0372  0.0458  0.0771  0.0771  0.1130  0.2353
# 4  0.0056  0.0267  0.0221  0.0561  0.0936  0.1146  0.0706  0.0996  0.1673
#
#       a10   ...       a51     a52     a53     a54     a55     a56     a57  \
# 0  0.2119   ...    0.0199  0.0096  0.0103  0.0093  0.0025  0.0044  0.0021
# 1  0.3759   ...    0.0107  0.0193  0.0118  0.0064  0.0042  0.0054  0.0049
# 2  0.1923   ...    0.0223  0.0121  0.0108  0.0057  0.0028  0.0079  0.0034
# 3  0.1838   ...    0.0135  0.0141  0.0190  0.0043  0.0036  0.0026  0.0024
# 4  0.1859   ...    0.0185  0.0072  0.0055  0.0074  0.0068  0.0084  0.0037
#
#       a58     a59     a60
# 0  0.0069  0.0060  0.0018
# ...

# %%
combine = [train,test]

# %%
X_train = train.drop("R",axis=1)
Y_train = train["R"]
X_train.shape , Y_train.shape
# Out:
# ((200, 60), (200,))

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 60 columns):
# a1     12 non-null float64
# a2     12 non-null float64
# a3     12 non-null float64
# a4     12 non-null float64
# a5     12 non-null float64
# a6     12 non-null float64
# a7     12 non-null float64
# a8     12 non-null float64
# a9     12 non-null float64
# a10    12 non-null float64
# a11    12 non-null float64
# a12    12 non-null float64
# a13    12 non-null float64
# a14    12 non-null float64
# a15    12 non-null float64
# a16    12 non-null float64
# a17    12 non-null float64
# a18    12 non-null float64
# a19    12 non-null float64
# a20    12 non-null float64
# a21    12 non-null float64
# a22    12 non-null float64
# a23    12 non-null float64
# a24    12 non-null float64
# a25    12 non-null float64
# a26    12 non-null float64
# a27    12 non-null float64
# a28    12 non-null float64
# a29    12 non-null float64
# a30    12 non-null float64
# ...

# %%
logmodel = LogisticRegression()

# %%
logmodel.fit(X_train, Y_train)
Y_pred = logmodel.predict(test)
acc_log = round(logmodel.score(X_train , Y_train) * 100, 2)
acc_log
# Out:
# 83.5

# %%
coeff_df = pd.DataFrame(train.columns.delete(0))
coeff_df.columns = ['Feature']
coeff_df["Correlation"] = pd.Series(logmodel.coef_[0])

coeff_df.sort_values(by='Correlation', ascending=False)
# Out:
#    Feature  Correlation
# 35     a37     1.137729
# 30     a32     0.943902
# 36     a38     0.844839
# 15     a17     0.690904
# 39     a41     0.667786
# 34     a36     0.550593
# 14     a16     0.542998
# 25     a27     0.528326
# 16     a18     0.517718
# 33     a35     0.479293
# 24     a26     0.429967
# 17     a19     0.298819
# 13     a15     0.246534
# 26     a28     0.150915
# 6       a8     0.083487
# 32     a34     0.046939
# 56     a58     0.018973
# 54     a56     0.009975
# 7       a9     0.008713
# 55     a57    -0.017841
# 49     a51    -0.017885
# 28     a30    -0.021204
# 59       R    -0.025556
# 52     a54    -0.045764
# 53     a55    -0.057285
# 58     a60    -0.058297
# 57     a59    -0.058644
# 40     a42    -0.064503
# 31     a33    -0.104717
# 50     a52    -0.116447
# 27     a29    -0.119041
# 51     a53    -0.124775
# 5       a7    -0.149305
# 0       a2    -0.279027
# 23     a25    -0.284025
# 2       a4    -0.286897
# 29     a31    -0.299376
# ...

# %%
Submission = pd.concat([test,Y_pred],axis=1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-122-067d935317a2> in <module>()
# ----> 1 Submission = pd.concat([test,Y_pred],axis=1)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, join_axes, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     223                        keys=keys, levels=levels, names=names,
#     224                        verify_integrity=verify_integrity,
# --> 225                        copy=copy, sort=sort)
#     226     return op.get_result()
#     227
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, join_axes, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     284                        ' only pd.Series, pd.DataFrame, and pd.Panel'
# ...

# %%
Submission
# Out:
#     Mine or Rock
# 0              0
# 1              0
# 2              0
# 3              1
# 4              0
# 5              1
# 6              0
# 7              0
# 8              0
# 9              0
# 10             0
# 11             0
